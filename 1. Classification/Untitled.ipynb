# %%
import pandas as pd
df=pd.read_csv('house-votes-84.csv')

# %%
df.head()
# Out:
#    republican  n  y n.1 y.1 y.2 y.3 n.2 n.3 n.4 y.4  ? y.5 y.6 y.7 n.5 y.8
# 0  republican  n  y   n   y   y   y   n   n   n   n  n   y   y   y   n   ?
# 1    democrat  ?  y   y   ?   y   y   n   n   n   n  y   n   y   y   n   n
# 2    democrat  n  y   y   n   ?   y   n   n   n   n  y   n   y   n   n   y
# 3    democrat  y  y   y   n   y   y   n   n   n   n  y   ?   y   y   y   y
# 4    democrat  n  y   y   n   y   y   n   n   n   n  n   n   y   y   y   y

# %%
df.columns=['party', 'infants', 'water', 'budget', 'physician', 'salvador',
       'religious', 'satellite', 'aid', 'missile', 'immigration', 'synfuels',
       'education', 'superfund', 'crime', 'duty_free_exports', 'eaa_rsa']

# %%
df
# Out:
#           party infants water budget physician salvador religious satellite  \
# 0    republican       n     y      n         y        y         y         n
# 1      democrat       ?     y      y         ?        y         y         n
# 2      democrat       n     y      y         n        ?         y         n
# 3      democrat       y     y      y         n        y         y         n
# 4      democrat       n     y      y         n        y         y         n
# 5      democrat       n     y      n         y        y         y         n
# 6    republican       n     y      n         y        y         y         n
# 7    republican       n     y      n         y        y         y         n
# 8      democrat       y     y      y         n        n         n         y
# 9    republican       n     y      n         y        y         n         n
# 10   republican       n     y      n         y        y         y         n
# 11     democrat       n     y      y         n        n         n         y
# 12     democrat       y     y      y         n        n         y         y
# 13   republican       n     y      n         y        y         y         n
# 14   republican       n     y      n         y        y         y         n
# 15     democrat       y     n      y         n        n         y         n
# 16     democrat       y     ?      y         n        n         n         y
# 17   republican       n     y      n         y        y         y         n
# 18     democrat       y     y      y         n        n         n         y
# 19     democrat       y     y      y         n        n         ?         y
# 20     democrat       y     y      y         n        n         n         y
# 21     democrat       y     ?      y         n        n         n         y
# 22     democrat       y     y      y         n        n         n         y
# 23     democrat       y     n      y         n        n         n         y
# 24     democrat       y     n      y         n        n         n         y
# 25     democrat       y     n      y         n        n         n         y
# 26     democrat       y     y      y         n        n         n         y
# 27   republican       y     n      n         y        y         n         y
# 28     democrat       y     y      y         n        n         n         y
# 29   republican       n     y      n         y        y         y         n
# ..          ...     ...   ...    ...       ...      ...       ...       ...
# 404  republican       n     n      n         y        y         y         n
# 405    democrat       y     n      y         n        y         y         n
# 406    democrat       n     n      n         y        y         y         n
# 407    democrat       y     n      y         n        n         y         y
# 408  republican       n     n      n         y        y         y         n
# 409  republican       n     n      n         y        y         y         n
# 410    democrat       y     n      y         n        n         y         y
# 411  republican       n     n      n         y        y         y         n
# 412  republican       y     y      y         y        y         y         y
# 413    democrat       y     y      y         n        n         n         y
# 414    democrat       n     y      y         n        n         y         y
# 415  republican       y     y      n         y        y         y         n
# 416    democrat       y     y      y         n        n         n         y
# 417    democrat       y     y      y         n        n         n         y
# 418    democrat       y     y      y         n        n         n         y
# 419  republican       y     y      y         y        y         y         y
# 420    democrat       n     y      y         n        y         y         y
# 421    democrat       n     n      y         n        n         y         y
# 422    democrat       n     y      y         n        n         y         y
# 423    democrat       n     y      y         n        n         ?         y
# 424    democrat       n     n      y         n        n         n         y
# 425    democrat       y     n      y         n        n         n         y
# 426  republican       n     n      n         y        y         y         y
# 427    democrat       ?     ?      ?         n        n         n         y
# 428    democrat       y     n      y         n        ?         n         y
# 429  republican       n     n      y         y        y         y         n
# 430    democrat       n     n      y         n        n         n         y
# 431  republican       n     ?      n         y        y         y         n
# 432  republican       n     n      n         y        y         y         ?
# 433  republican       n     y      n         y        y         y         n
#
#     aid missile immigration synfuels education superfund crime  \
# 0     n       n           n        n         y         y     y
# 1     n       n           n        y         n         y     y
# 2     n       n           n        y         n         y     n
# 3     n       n           n        y         ?         y     y
# 4     n       n           n        n         n         y     y
# 5     n       n           n        n         n         ?     y
# 6     n       n           n        n         n         y     y
# 7     n       n           n        n         y         y     y
# 8     y       y           n        n         n         n     n
# 9     n       n           n        ?         ?         y     y
# 10    n       n           n        y         ?         y     y
# 11    y       y           n        n         n         y     n
# 12    y       ?           y        y         ?         n     n
# 13    n       n           n        n         y         ?     ?
# 14    n       n           y        n         y         y     ?
# 15    y       ?           y        y         y         ?     n
# 16    y       y           n        n         n         y     n
# 17    n       n           n        n         ?         y     y
# 18    y       y           n        y         n         n     n
# 19    y       n           n        y         n         n     n
# 20    y       y           n        n         n         ?     ?
# 21    y       y           n        n         ?         n     n
# 22    y       y           n        n         n         n     n
# 23    y       y           n        n         n         n     n
# 24    y       y           y        n         n         n     n
# 25    y       y           n        y         n         n     n
# 26    y       y           n        y         n         n     n
# 27    y       y           n        n         y         y     y
# 28    y       y           n        y         n         n     n
# 29    n       n           n        n         y         y     y
# ..   ..     ...         ...      ...       ...       ...   ...
# 404   n       n           n        n         y         y     y
# 405   n       y           y        n         n         y     y
# 406   n       n           n        y         y         y     y
# 407   y       y           n        n         y         ?     y
# 408   n       n           n        n         y         y     y
# 409   n       n           n        y         y         y     y
# 410   y       y           y        y         n         n     n
# 411   n       n           y        n         y         y     y
# 412   y       n           y        ?         ?         ?     y
# 413   y       y           n        n         n         n     n
# 414   y       ?           y        n         n         n     n
# 415   n       n           y        n         n         y     y
# 416   y       y           y        y         n         y     n
# 417   y       n           y        n         n         n     n
# 418   y       y           n        n         n         n     n
# 419   y       n           y        n         n         y     y
# 420   y       n           n        y         n         y     n
# 421   y       y           n        y         n         n     n
# 422   y       y           n        y         n         n     y
# 423   y       y           y        y         n         ?     y
# 424   y       n           y        y         n         n     n
# 425   y       y           y        n         n         n     n
# 426   y       n           y        n         y         y     y
# 427   y       y           y        n         n         y     n
# 428   y       y           y        n         y         n     ?
# 429   n       y           y        n         y         y     y
# 430   y       y           y        n         n         n     n
# 431   n       n           n        y         y         y     y
# 432   ?       ?           ?        n         y         y     y
# 433   n       n           y        n         y         y     y
#
#     duty_free_exports eaa_rsa
# 0                   n       ?
# 1                   n       n
# 2                   n       y
# 3                   y       y
# 4                   y       y
# 5                   y       y
# 6                   ?       y
# 7                   n       y
# 8                   ?       ?
# 9                   n       n
# 10                  ?       ?
# 11                  ?       ?
# 12                  y       ?
# 13                  n       ?
# 14                  n       ?
# 15                  n       y
# 16                  y       y
# 17                  n       n
# 18                  y       y
# 19                  y       y
# 20                  y       y
# 21                  y       y
# 22                  y       y
# 23                  y       ?
# 24                  y       y
# 25                  y       y
# 26                  y       y
# 27                  n       y
# 28                  y       y
# 29                  n       n
# ..                ...     ...
# 404                 n       y
# 405                 n       y
# 406                 n       n
# 407                 y       y
# 408                 n       n
# 409                 n       y
# 410                 n       y
# 411                 n       y
# 412                 n       y
# 413                 n       y
# 414                 n       y
# 415                 n       y
# 416                 n       y
# 417                 n       y
# 418                 n       y
# 419                 n       y
# 420                 y       y
# 421                 y       y
# 422                 y       y
# 423                 y       y
# 424                 y       ?
# 425                 y       y
# 426                 n       y
# 427                 y       y
# 428                 y       y
# 429                 n       y
# 430                 n       y
# 431                 n       y
# 432                 n       y
# 433                 ?       n
#
# [434 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434 entries, 0 to 433
# Data columns (total 17 columns):
# party                434 non-null object
# infants              434 non-null object
# water                434 non-null object
# budget               434 non-null object
# physician            434 non-null object
# salvador             434 non-null object
# religious            434 non-null object
# satellite            434 non-null object
# aid                  434 non-null object
# missile              434 non-null object
# immigration          434 non-null object
# synfuels             434 non-null object
# education            434 non-null object
# superfund            434 non-null object
# crime                434 non-null object
# duty_free_exports    434 non-null object
# eaa_rsa              434 non-null object
# dtypes: object(17)
# memory usage: 57.7+ KB
